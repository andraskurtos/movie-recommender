# %%
import pandas as pd

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
movies = pd.read_csv('ml-latest-small/movies.csv')

print(ratings.head())
print(movies.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
from surprise import Dataset, Reader, SVD
from surprise.model_selection import cross_validate

reader = Reader(rating_scale=(0.5, 5.0))
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']],   reader)
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8715  0.8717  0.8774  0.8696  0.8762  0.8733  0.0030
# MAE (testset)     0.6682  0.6696  0.6722  0.6683  0.6743  0.6705  0.0024
# Fit time          1.29    1.25    1.36    1.23    1.28    1.28    0.04
# Test time         0.16    0.18    0.10    0.11    0.10    0.13    0.03
# {'test_rmse': array([0.87151688, 0.87166951, 0.87738506, 0.86957337, 0.87620339]),
#  'test_mae': array([0.66822989, 0.66961286, 0.67218749, 0.66833218, 0.67428165]),
#  'fit_time': (1.2923121452331543,
#   1.2504644393920898,
#   1.3581411838531494,
#   1.2336204051971436,
#   1.2837297916412354),
#  'test_time': (0.16121292114257812,
#   0.17905950546264648,
#   0.10254335403442383,
#   0.10969066619873047,
#   0.10268402099609375)}
